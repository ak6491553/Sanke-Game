# %%
import requests
web_url = 'http://edunetfoundation.org/'
response = requests.get(web_url)
response.headers
# Out:
# {'Date': 'Fri, 17 Jan 2025 06:45:02 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Set-Cookie': 'utm_source=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.edunetfoundation.org, utm_medium=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.edunetfoundation.org, utm_term=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.edunetfoundation.org, utm_content=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.edunetfoundation.org, utm_campaign=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.edunetfoundation.org, gclid=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.edunetfoundation.org, handl_original_ref=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.edunetfoundation.org, handl_landing_page=http%3A%2F%2Fedunetfoundation.org%2F; expires=Sun, 16-Feb-2025 06:45:03 GMT; Max-Age=2592000; path=/; domain=.edunetfoundation
# ...

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!doctype html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0">\n\t<link rel="profile" href="//gmpg.org/xfn/11">\n\t\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<link rel="dns-prefetch" href="//fonts.googleapis.com">\n<link rel="dns-prefetch" href="//s.w.org">\n\n\t<!-- This site is optimized with the Yoast SEO plugin v19.10 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Home - Edunet Foundation</title>\n\t<link rel="canonical" href="https://edunetfoundation.org/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="website" />\n\t<meta property="og:title" content="Home - Edunet Foundation" />\n\t<meta property="og:description" content="ABOUT US Technology innovation and Social Enterprise are key to India&#8217;s success. Edunet Foundation is helping bridge the skill d
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

def scrape_example():
    url = 'http://edunetfoundation.org/'
    response = requests.get(url)

    if response.status_code== 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.title.get_text()
        print(f'Title of the page: {title}')
    else:
        print(f"Faild to retrieve the page. Status code: {response.status_code}")

# %%
if __name__ == "__main__":
    scrape_example()
# Out:
# Title of the page: Home - Edunet Foundation

# %% [markdown]
# # lab 59

# %%
# IMport libraries

import requests
from bs4 import BeautifulSoup

# %%
url = 'http://edunetfoundation.org/'
response = requests.get(url)
if response.status_code == 200:
    print("successfully fetched the web page!")
else:
    print(f" Failed to fetch the web page. Status code: {response.status_code}")
# Out:
# successfully fetched the web page!

# %%
soup = BeautifulSoup(response.text, 'lxml')

# %%
title = soup.title.string
print(f"Page Title: {title}")
# Out:
# Page Title: Home - Edunet Foundation

# %%
links = soup.find_all('a')
for link in links:
    href = link.get('href')
    text = link.get_text()
    print(f"Link text: {text}, URL: {href}")
# Out:
# Link text: Edunet Foundation, URL: https://edunetfoundation.org
# Link text:
#
#
#
#
#
# , URL: https://edunetfoundation.org
# Link text: Home, URL: https://edunetfoundation.org/
# Link text: About, URL: #
# Link text: Edunet Foundation, URL: https://edunetfoundation.org/about-us/
# Link text: Our Team, URL: https://edunetfoundation.org/our-team/
# Link text: Partners & Collaborators, URL: https://edunetfoundation.org/partners-collaborators/
# Link text: Programs, URL: #
# Link text: Schools, URL: https://edunetfoundation.org/schools/
# Link text: Colleges, URL: https://edunetfoundation.org/colleges/
# Link text: Vocational, URL: https://edunetfoundation.org/vocational/
# Link text: Communities, URL: https://edunetfoundation.org/communities/
# Link text: Impact, URL: https://edunetfoundation.org/stories/
# Link text: Get Involved, URL: https://edunetfoundation.org/get-involved/
# Link text: Contact, URL: https://edunetfoundation.org/contact/
# ...

# %%
paragraphs = soup.find_all('p')
for paragraph in paragraphs:
    print(paragraph.get_text())
# Out:
# Edunet Foundation
#
# Edunet Foundation is helping bridge the skill deficit that the country is facing,  working to leverage and realize the mammoth potential of India’s young population. Focus is to provide opportunities to all, irrespective of location, gender, religion or socio-economic constraints.
# IR 4.0 & 5.0 Tech skills for now
# meta human skills for forever
# Access to these for all
# In addition to working with students directly, we believe in empowering and equipping teachers and trainers who in turn work with learners on a long term basis. We help people who are helping people.
# We are building the nation’s largest educational network focused on national good.
# The first generation to go for higher education in her family, Gunasundari hails from the town of Thanjavur, Tamil Nadu. Her story of how her hard work paid off to make her a role-model not just for her siblings but her whole community, is as inspiring as it gets.
# Pan-India coverage
# ...

# %% [markdown]
# # Lab 61

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

def fetch_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text

    except requests.exceptions.RequestException as e:
        print(f"Error Fetching {url}: {e}")
        return None

def extract_links(html, base_url):
    soup = BeautifulSoup(html, 'lxml')
    links = []
    for link in soup.find_all('a', href=True):
        full_url = urljion(base_url, link['hre'])
        links.append(full_url)
    return links

# %%
def crawl(start_url, max_depth=2):
    visited = set()
    to_visit = [(start_url, 0)]
    while to_visit:
        current_url, depth = to_visit.pop(0)
        if depth > max_depth:
            continue

        if current_url
